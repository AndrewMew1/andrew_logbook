# %% [markdown]
# # In this tutorial, you will learn how to develop a Machine Learning classifier for the automatic detection of handwritten digits.
#
# # The challenge of handwritten digit classification in machine learning revolves around the creation of algorithms and models designed to accurately identify and assign labels to handwritten digits. Throughout this tutorial, we will primarily utilize the scikit-learn (sklearn) library for this purpose.

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
# Load the MNIST dataset
digits = datasets.load_digits()

# %%
# Split the data into features and labels
X = digits.images
y = digits.target

# %%
X = digits['images']
y = digits['target']

print(f'Images (x) Shape : {X.shape}')
print(f'Target (y) Shape : {y.shape}')
# Out:
# Images (x) Shape : (1797, 8, 8)
# Target (y) Shape : (1797,)

# %%
# Display sample data
plt.imshow(X[9], cmap=plt.cm.gray )
print(f'True  Value: {y[9]}')
# Out:
# True  Value: 9

# %%
#
# Your code to display any other sample image and its true value.
#
plt.imshow(X[1], cmap=plt.cm.gray )
print(f'True  Value: {y[1]}')
# Out:
# True  Value: 1

# %% [markdown]
# The following plot prints a bunch of digits. However, the X-axis of the subplot looks a bit messy from the second row. Improve the plot to make it look better.

# %%
# Display sample data i.e. a bunch of images.
fig = plt.figure(figsize=(6, 6))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(30):
    plt.subplot(5, 9, i + 1)
    plt.imshow(X[i], cmap=plt.cm.gray )
    plt.title(f"True: {y[i]}")

plt.show()

# %%
# Flatten the images into a 1D array
n_samples = len(X)
X = X.reshape((n_samples, -1))

# %%
# Split the dataset into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

# %%
# Flatten the images into a 1D array
n_samples = len(X)
X = X.reshape((n_samples, -1))

# %%
# Create an MLP classifier with 2 hidden layers with 100 neurons in each layer
clf = MLPClassifier(hidden_layer_sizes=(100, 100), max_iter=1000)

# %%
# Train the classifier on the training data
clf.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(100, 100), max_iter=1000)

# %%
# Make predictions on the test data
y_pred = clf.predict(X_test)

# %%
# Calculate the accuracy of the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 96.33%

# %%
# Generate a classification report
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        89
#            1       0.93      0.98      0.95        90
#            2       0.98      0.97      0.97        92
#            3       0.98      0.97      0.97        93
#            4       0.96      1.00      0.98        76
#            5       0.94      0.94      0.94       108
#            6       0.98      0.98      0.98        89
#            7       0.97      0.99      0.98        78
#            8       0.99      0.86      0.92        92
#            9       0.93      0.97      0.95        92
#
#     accuracy                           0.96       899
#    macro avg       0.96      0.96      0.96       899
# weighted avg       0.96      0.96      0.96       899

# %%
# Plot the confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_)
disp.plot()

# %% [markdown]
# # Next, try three other different MLP models with various configurations, such as the number of hidden layers, the number of neurons in each hidden layer, different learning rates, different numbers of iterations to train the model, or different optimization functions.
#
# #Use the configuration of your choice.
#
# # Use the MLPClassifier() class from scikit-learn, which you can find here: https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html .
#
# # You should store the accuracy of each model in a separate variable or a list.
#
# # Create a bar graph comparing the accuracy of all the models. To do this, you can use the 'barh' class from the Python pyplot library, which is explained here:
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.barh.html
#
# # **Important -** Document in your lab logbook:
#
# # 1. The output of the neural network model provided in task 1.
# # 2. A bar plot comparing the accuracy of the different MLP models from your code.

# %% [markdown]
# # MODEL 1

# %%
A = digits.images
B = digits.target

# %%
A = digits['images']
B = digits['target']

print(f'Images (x) Shape : {A.shape}')
print(f'Target (y) Shape : {B.shape}')
# Out:
# Images (x) Shape : (1797, 8, 8)
# Target (y) Shape : (1797,)

# %%
n_samples = len(A)
A = A.reshape((n_samples, -1))
A_train, A_test, B_train, B_test = train_test_split(A, B, test_size=0.5, random_state=0)

# %%
n_samples = len(A)
A = A.reshape((n_samples, -1))
andr = MLPClassifier(hidden_layer_sizes=(500, 500), max_iter=4000)

# %%
andr.fit(A_train, B_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(500, 500), max_iter=4000)

# %%
B_predict = andr.predict(A_test)
accur = accuracy_score(B_test, B_predict)
print(f'Accuracy: {accur * 100:.2f}%')
# Out:
# Accuracy: 97.66%

# %% [markdown]
# # MODEL 2

# %%
n_samples = len(A)
A = A.reshape((n_samples, -1))
A_train, A_test, B_train, B_test = train_test_split(A, B, test_size=0.5, random_state=0)

# %%
n_samples = len(A)
A = A.reshape((n_samples, -1))
andre = MLPClassifier(hidden_layer_sizes=(600, 600), max_iter=3000)

# %%
andre.fit(A_train, B_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(600, 600), max_iter=3000)

# %%
B_predict = andre.predict(A_test)
accu = accuracy_score(B_test, B_predict)
print(f'Accuracy: {accu * 100:.2f}%')
# Out:
# Accuracy: 97.11%

# %% [markdown]
# # MODEL 3

# %%
n_samples = len(A)
A = A.reshape((n_samples, -1))
A_train, A_test, B_train, B_test = train_test_split(A, B, test_size=0.5, random_state=0)

# %%
n_samples = len(A)
A = A.reshape((n_samples, -1))
andrey = MLPClassifier(hidden_layer_sizes=(1000, 1000), max_iter=500)

# %%
andrey.fit(A_train, B_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(1000, 1000), max_iter=500)

# %%
B_predict = andrey.predict(A_test)
accura = accuracy_score(B_test, B_predict)
print(f'Accuracy: {accura * 100:.2f}%')
# Out:
# Accuracy: 98.11%

# %% [markdown]
# # GRAPH

# %%
accuracy_numbers = [accuracy, accur, accu, accura]

print(accuracy_numbers)
# Out:
# [0.9632925472747497, 0.9766407119021134, 0.9710789766407119, 0.9810901001112347]

# %%
x_pos = np.arange(len(accuracy_numbers))
labels = ['Model 0', 'Model 1', 'Model 2', 'Model 3']
plt.bar(x_pos, accuracy_numbers)
plt.xticks(x_pos, labels)
plt.ylim(min(accuracy_numbers) - 0.02, max(accuracy_numbers) + 0.02)
plt.bar(x_pos, accuracy_numbers, color=['gree', 'b', 'green', 'violet'])
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison')
plt.show()

# %% [markdown]
# # Write code to display 10 images from X_test, along with their true values and predicted values for any MLP model. Your plot should resemble the following:
#
# # Hint: You'll need to use the 'reshape' function.
#
# ![image.png](data:image/png;base64,...)

# %%
#
#
#  Your code to display the above plot
#
#
X_test_reshaped = X_test.reshape((n_samples, -1))

fig = plt.figure(figsize=(9, 5))
fig.subplots_adjust(left=0, right=1, bottom=0, top=0.95, hspace=0.3, wspace=0.3)

for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_test_reshaped[i], cmap=plt.cm.gray)
    plt.title(f"True: {y_true[i]}\nPred: {y_pred[i]}")
    plt.axis('off')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[252], line 6
#       1 #
#       2 #
#       3 #  Your code to display the above plot
#       4 #
#       5 #
# ----> 6 X_test_reshaped = X_test.reshape((n_samples, -1))
#       8 fig = plt.figure(figsize=(9, 5))
#       9 fig.subplots_adjust(left=0, right=1, bottom=0, top=0.95, hspace=0.3, wspace=0.3)
#
# ValueError: cannot reshape array of size 57536 into shape (1797,newaxis)
